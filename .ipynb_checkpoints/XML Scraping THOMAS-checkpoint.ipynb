# %% [markdown]
# ## XML Web Scraping Roll Call Data

# %%
#import libs
import urllib
import xml.etree.ElementTree as ET
import re
import pandas as pd
import numpy as np
from sklearn.externals import joblib
from time import sleep

# %%
#test
#request
url = "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1142/vote_114_2_00081.xml"
req = urllib.request.Request(url)
with urllib.request.urlopen(req) as response:
    the_page = response.read()

# %%
#begin parse with root
root = ET.fromstring(the_page)

# %%
#checkout children
children = {}
for child in root:
    print(child.tag, ":", child.text)
# Out:
# congress : 114
# session : 2
# congress_year : 2016
# vote_number : 163
# vote_date : December 10, 2016,  12:57 AM
# modify_date : December 10, 2016,  01:26 AM
# vote_question_text : On the Motion (Motion to Concur in the House Amendment to S. 612)
# vote_document_text : A bill to designate the Federal building and United States courthouse located at 1300 Victoria Street in Laredo, Texas, as the "George P. Kazen Federal Building and United States Courthouse".
# vote_result_text : Motion Agreed to (78-21)
# question : On the Motion
# vote_title : Motion to Concur in the House Amendment to S. 612
# majority_requirement : 1/2
# vote_result : Motion Agreed to
# document :
#
# amendment :
#
# count :
#
# tie_breaker :
#
# members :

# %%
#bill_info
info={}
for key, value in master_roots_1.items():
    bill_info={}
    for child in value:
        bill_info[child.tag] = child.text
    info[key] = bill_info

# %%
info_2 = {}
for key, value in master_roots_2.items():
    bill_info={}
    for child in value:
        bill_info[child.tag] = child.text
    info_2[str(int(key)+339)] = bill_info

# %%
#document
for element in root[-5]:
    print (element)
# Out:
# <Element 'document_congress' at 0x000001F540702B88>
# <Element 'document_type' at 0x000001F540702BD8>
# <Element 'document_number' at 0x000001F540702C28>
# <Element 'document_name' at 0x000001F540702C78>
# <Element 'document_title' at 0x000001F540702CC8>
# <Element 'document_short_title' at 0x000001F540702D18>

# %%
#amendment
for element in root[-4]:
    print (element)
# Out:
# <Element 'amendment_number' at 0x000001F540702DB8>
# <Element 'amendment_to_amendment_number' at 0x000001F540702E58>
# <Element 'amendment_to_amendment_to_amendment_number' at 0x000001F540702EF8>
# <Element 'amendment_to_document_number' at 0x000001F540702F98>
# <Element 'amendment_to_document_short_title' at 0x000001F540703048>
# <Element 'amendment_purpose' at 0x000001F540703098>

# %%
#count
for element in root[-3]:
    print (element)
# Out:
# <Element 'yeas' at 0x000001F540703188>
# <Element 'nays' at 0x000001F5407031D8>
# <Element 'present' at 0x000001F540703228>
# <Element 'absent' at 0x000001F540703278>

# %%
#tie-breaker
for i in root[-2]:
    print (i)
# Out:
# <Element 'by_whom' at 0x000001F540703318>
# <Element 'tie_breaker_vote' at 0x000001F540703368>

# %%
#members
for element in root[-1][0]:
    print (element.text)
# Out:
# Alexander (R-TN)
# Alexander
# Lamar
# R
# TN
# Nay
# S289

# %%
#members children
for i in root[-1][0]:
    print (i)
# Out:
# <Element 'member_full' at 0x000001F540703458>
# <Element 'last_name' at 0x000001F5407034A8>
# <Element 'first_name' at 0x000001F5407034F8>
# <Element 'party' at 0x000001F540703548>
# <Element 'state' at 0x000001F540703598>
# <Element 'vote_cast' at 0x000001F5407035E8>
# <Element 'lis_member_id' at 0x000001F540703638>

# %%
#parse members
member_names = []
parties = []
states = []
votes = []
ids = []
for element in root[-1]:
    member_names.append(element[1].text + ' '+ element[2].text)
    parties.append(element[3].text)
    states.append(element[4].text)
    votes.append(element[5].text)
    ids.append(element[6].text)

# %%
member_data = pd.DataFrame.from_dict({'member': member_names, 'party': parties, 'state': states, 'vote': votes, 'idx': ids})

# %%
member_data.T
# Out:
#                      0             1              2              3   \
# idx                S289          S340           S354           S317
# member  Alexander Lamar  Ayotte Kelly  Baldwin Tammy  Barrasso John
# party                 R             R              D              R
# state                TN            NH             WI             WY
# vote                Nay           Nay            Yea            Nay
#
#                     4                   5          6            7   \
# idx               S330                S341       S342         S370
# member  Bennet Michael  Blumenthal Richard  Blunt Roy  Booker Cory
# party                D                   D          R            D
# state               CO                  CT         MO           NJ
# vote               Nay                 Yea        Nay          Yea
#
#                   8              9     ...              90             91  \
# idx             S343           S223    ...            S303           S384
# member  Boozman John  Boxer Barbara    ...      Thune John  Tillis Thomas
# party              R              D    ...               R              R
# state             AR             CA    ...              SD             NC
# vote             Nay     Not Voting    ...             Nay            Nay
#
#                 92         93            94           95                96  \
# idx           S351       S326          S299         S327              S366
# member  Toomey Pat  Udall Tom  Vitter David  Warner Mark  Warren Elizabeth
# party            R          D             R            D                 D
# state           PA         NM            LA           VA                MA
# vote           Nay        Yea           Nay          Yea               Yea
#
#                         97            98         99
# idx                   S316          S318       S247
# member  Whitehouse Sheldon  Wicker Roger  Wyden Ron
# party                    D             R          D
# state                   RI            MS         OR
# vote                   Yea           Nay        Yea
#
# [5 rows x 100 columns]

# %%
def get_votes(root):
    votes = []
    for element in root[-1]:
        votes.append(element[5].text)
    return votes
def get_member_id(root):
    ids = []
    for element in root[-1]:
        ids.append(element[6].text)

# %%
def padded(num):
    l = len(str(num))
    zeros = "0"*(5-l)
    new = zeros+str(num)
    return new

# %%
#create master dict of roots for each bill

# %%
#repeat the above process, but create a master dict of all roots
master_roots = {}
for i in range(1,3):
    n= padded(i)
    url = "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1141/vote_114_1_"+ n + ".xml"
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        the_page = response.read()
    root = ET.fromstring(the_page)
    master_roots[n] = root

# %%
#it works
master_roots
# Out:
# {'00001': <Element 'roll_call_vote' at 0x000001F541D0F7C8>,
#  '00002': <Element 'roll_call_vote' at 0x000001F541D49548>}

# %%
#it works
for i in range(1,164):
    n = padded(i)
    #print (master_roots[n][-1][0][0].text)

# %% [markdown]
# ### Create a dict of all the roll call votes

# %%
#session 1
master_roots_1 = {}
for i in range(1,340):
    n= padded(i)
    url = "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1141/vote_114_1_"+ n + ".xml"
    req = urllib.request.Request(url)
    with urllib.request.urlopen(req) as response:
        the_page = response.read()
    root = ET.fromstring(the_page)
    master_roots_1[n] = root

# %%
#session 2
master_roots_2 = {}
for i in range(1,164):
    try:
        n= padded(i)
        url = "https://www.senate.gov/legislative/LIS/roll_call_votes/vote1142/vote_114_2_"+ n + ".xml"
        req = urllib.request.Request(url)
        with urllib.request.urlopen(req) as response:
            the_page = response.read()
        root = ET.fromstring(the_page)
        master_roots_2[n] = root
        sleep(2)
    except:
        continue

# %%
master_roots_2['00121']
# Out:
# <Element 'roll_call_vote' at 0x000001F5511DEF48>

# %%
senators = []
for i in range(100):
    senator = master_roots['00001'][-1][i][0].text
    senators.append(senator)

# %%
senators[:10]
# Out:
# ['Alexander (R-TN)',
#  'Ayotte (R-NH)',
#  'Baldwin (D-WI)',
#  'Barrasso (R-WY)',
#  'Bennet (D-CO)',
#  'Blumenthal (D-CT)',
#  'Blunt (R-MO)',
#  'Booker (D-NJ)',
#  'Boozman (R-AR)',
#  'Boxer (D-CA)']

# %% [markdown]
# ### Create votes table

# %%
#make a dict of all the votes for each bill
votes_dict_1 = {}
for key, value in master_roots_1.items():
    votes_dict_1[key] = get_votes(value)

# %%
votes_dict_2 = {}
for key, value in master_roots_2.items():
    votes_dict_2[str(int(key)+339)] = get_votes(value)

# %%
bills_df = pd.DataFrame.from_dict(votes_dict_1).join(pd.DataFrame.from_dict(votes_dict_2)).T

# %%
bills_df.columns = senators

# %%
bills_df.index.name = 'vote_number'

# %%
bills_df.shape
# Out:
# (438, 100)

# %%
bills_df
# Out:
# Index(['00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008',
#        '00009', '00010',
#        ...
#        '462', '478', '487', '492', '494', '496', '497', '500', '501', '502'],
#       dtype='object', name='vote_number', length=438)

# %% [markdown]
# #### Get outcomes

# %%
def get_outcome(root):
    return root[-6].text

# %%
#make a dict of all outcomes
outcomes_dict_1 = {}
for key, value in master_roots_1.items():
    outcomes_dict_1[key] = get_outcome(value)
outcomes_dict_2 = {}
for key, value in master_roots_2.items():
    outcomes_dict_2[str(int(key)+339)] = get_outcome(value)

# %%
total_outcomes = []
for key, value in outcomes_dict_2.items():
    outcomes_dict_1[key] = value

# %%
outcomes = pd.Series(outcomes_dict_1)
outcomes.name = 'outcome'

# %%
votes = bills_df.join(outcomes)

# %%
new_index = [str(int(x)) for x in votes.index.values]

# %%
votes.index = new_index

# %%
votes
# Out:
#     Alexander (R-TN) Ayotte (R-NH) Baldwin (D-WI) Barrasso (R-WY)  \
# 1                Nay           Nay            Yea             Nay
# 2                Yea           Yea            Yea             Yea
# 3                Yea           Yea            Nay             Yea
# 4                Yea           Yea            Nay             Yea
# 5                Yea           Yea            Nay             Yea
# 6                Yea           Yea            Yea             Yea
# 7                Yea           Yea            Nay             Yea
# 8                Nay           Nay            Yea             Nay
# 9                Nay           Nay            Nay             Yea
# 10               Yea           Yea            Yea             Yea
# 11               Yea           Yea            Yea             Nay
# 12               Yea           Yea            Yea             Nay
# 13               Yea           Yea            Yea             Nay
# 14               Yea           Nay            Nay             Yea
# 15               Yea           Yea            Nay             Yea
# 16               Yea           Yea            Nay             Yea
# 17               Yea           Nay            Nay             Yea
# 18               Yea           Yea            Yea             Yea
# 19               Yea           Yea            Yea             Nay
# 20               Yea           Nay            Nay             Yea
# 21               Yea           Yea            Nay             Yea
# 22               Nay           Yea            Yea             Nay
# 23               Yea           Yea            Yea             Yea
# 24               Yea           Yea            Nay             Yea
# 25               Yea           Yea            Nay             Yea
# 26               Yea           Yea            Nay             Yea
# 27               Yea           Yea            Nay             Yea
# 26                    Motion to Table Agreed to
# 27                    Motion to Table Agreed to
# 28                    Motion to Table Agreed to
# 29                      Cloture Motion Rejected
# 30                      Cloture Motion Rejected
# ..                                          ...
# 409                          Amendment Rejected
# 410                                 Bill Passed
# 411                        Nomination Confirmed
# 412                     Cloture Motion Rejected
# 413                     Cloture Motion Rejected
# 414                    Cloture Motion Agreed to
# 415                            Motion Agreed to
# 416                         Amendment Agreed to
# 417                    Cloture Motion Agreed to
# 418                            Motion Agreed to
# 419                         Amendment Agreed to
# 420                   Motion to Table Agreed to
# 430                         Amendment Agreed to
# 437                                 Bill Passed
# 448                      Motion to Table Failed
# 452                    Cloture Motion Agreed to
# 453                      Motion to Table Failed
# 454                            Motion Agreed to
# 456                            Motion Agreed to
# 461                      Motion to Table Failed
# 462                            Motion Agreed to
# 478                            Motion Agreed to
# 487                             Veto Overridden
# 492   Cloture on the Motion to Proceed Rejected
# 494                                 Bill Passed
# 496                            Motion Agreed to
# 497                    Cloture Motion Agreed to
# 500                            Motion Agreed to
# 501                    Cloture Motion Agreed to
# 502                            Motion Agreed to
#
# [438 rows x 101 columns]

# %%
#export the bills to .csv and save for later

# %%
votes.shape
# Out:
# (438, 101)

# %%
votes.to_csv('votes.csv')

# %%
votes = pd.read_csv('votes.csv', index_col=0)

# %%
df = votes.replace({'Nay': 0, 'Yea': 1, 'Not Voting': 0, 'Present': 1})

# %%
outcomes = df.outcome.unique()

# %%
list(outcomes)
# Out:
# ['Amendment Rejected',
#  'Bill Passed',
#  'Cloture on the Motion to Proceed Agreed to',
#  'Motion to Table Agreed to',
#  'Amendment Agreed to',
#  'Motion for Attendance Agreed to',
#  'Cloture Motion Rejected',
#  'Cloture Motion Agreed to',
#  'Cloture on the Motion to Proceed Rejected',
#  'Nomination Confirmed',
#  'Motion to Table Failed',
#  'Motion to Proceed Agreed to',
#  'Joint Resolution Passed',
#  'Veto Sustained',
#  'Motion Rejected',
#  'Concurrent Resolution Agreed to',
#  'Motion Agreed to',
#  'Conference Report Agreed to',
#  'Resolution Agreed to',
#  'Veto Overridden']

# %%
outcome_replacements = {'Amendment Rejected': 0,
 'Bill Passed': 1,
 'Cloture on the Motion to Proceed Agreed to': 1,
 'Motion to Table Agreed to': 1,
 'Amendment Agreed to': 1,
 'Motion for Attendance Agreed to': 1,
 'Cloture Motion Rejected': 0,
 'Cloture Motion Agreed to': 1,
 'Cloture on the Motion to Proceed Rejected': 0,
 'Nomination Confirmed': 1,
 'Motion to Table Failed': 0,
 'Motion to Proceed Agreed to': 1,
 'Joint Resolution Passed': 1,
 'Veto Sustained': 0,
 'Motion Rejected': 0,
 'Concurrent Resolution Agreed to': 1,
 'Motion Agreed to': 1,
 'Conference Report Agreed to': 1,
 'Resolution Agreed to': 1,
 'Veto Overridden': 1}

# %%
df = df.replace(outcome_replacements)

# %%
df.to_csv('cleaned_votes.csv', index=False)

# %%
fixers = df.select_dtypes(exclude=[np.number])

# %% [markdown]
# #### Bill info

# %%
url = "https://www.senate.gov/legislative/LIS/roll_call_lists/vote_menu_114_2.xml"
req = urllib.request.Request(url)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
root1 = ET.fromstring(the_page)

# %%
url = "https://www.senate.gov/legislative/LIS/roll_call_lists/vote_menu_114_1.xml"
req = urllib.request.Request(url)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
root2 = ET.fromstring(the_page)

# %%
for child in root1:
    print(child.tag, ":", child.text)
# Out:
# congress : 114
# session : 2
# congress_year : 2016
# votes :

# %%
bills = {}
for vote in root1[-1]:
    pieces = {}
    bills[vote[0].text] = pieces
    for element in vote:
        pieces[element.tag] = element.text
    pieces['yea'] = (vote[-2][0].text)
    pieces['nay'] = (vote[-2][1].text)
        


bills2 = {}
for vote in root2[-1]:
    pieces = {}
    bills2[vote[0].text] = pieces
    for element in vote:
        pieces[element.tag] = element.text
    pieces['yea'] = (vote[-2][0].text)
    pieces['nay'] = (vote[-2][1].text)

# %%
bills_114_2 = pd.DataFrame(bills).T.drop('vote_tally', axis=1)
bills_114_1 = pd.DataFrame(bills2).T.drop('vote_tally', axis=1)

# %%
bills_114_1
# Out:
#            issue nay                             question     result  \
# 00001    H.R. 26  66                    On the Amendment    Rejected
# 00002    H.R. 26   4               On Passage of the Bill     Passed
# 00003       S. 1  32  On Cloture on the Motion to Proceed  Agreed to
# 00004       S. 1  42              On the Motion to Table   Agreed to
# 00005       S. 1  46              On the Motion to Table   Agreed to
# 00006       S. 1   5                    On the Amendment   Agreed to
# 00007       S. 1  45                    On the Amendment    Rejected
# 00008       S. 1  58                    On the Amendment    Rejected
# 00009       S. 1  45                    On the Amendment    Rejected
# 00010       S. 1   1                    On the Amendment   Agreed to
# 00011       S. 1  40                    On the Amendment    Rejected
# 00012       S. 1  49                    On the Amendment    Rejected
# 00013       S. 1  44                    On the Amendment    Rejected
# 00014       S. 1  45                    On the Amendment    Rejected
# 00015       S. 1  46              On the Motion to Table   Agreed to
# 00016       S. 1  42              On the Motion to Table   Agreed to
# 00017       S. 1  47                    On the Amendment    Rejected
# 00018       S. 1  23                    On the Amendment   Agreed to
# 00019       S. 1  47                    On the Amendment    Rejected
# 00020       S. 1  46                    On the Amendment    Rejected
# 00021       S. 1  33                    On the Amendment   Agreed to
# 00022       S. 1  54                    On the Amendment    Rejected
# 00023       S. 1   5         On the Motion for Attendance  Agreed to
# 00024       S. 1  42              On the Motion to Table   Agreed to
# 00025       S. 1  38              On the Motion to Table   Agreed to
# 00026       S. 1  43              On the Motion to Table   Agreed to
# 00027       S. 1  41              On the Motion to Table   Agreed to
# 00028       S. 1  45              On the Motion to Table   Agreed to
# 00029       S. 1  39               On the Cloture Motion    Rejected
# 00030       S. 1  39                On the Cloture Motion   Rejected
# ...          ...  ..                                  ...        ...
# 00310      PN420   7                    On the Nomination  Confirmed
# 00311  H.R. 3762  46              On the Motion to Table   Agreed to
# 00312  H.R. 3762  44                    On the Amendment    Rejected
# 00313  H.R. 3762  55                       On the Motion    Rejected
# 00314  H.R. 3762  52                    On the Amendment    Rejected
# 00315  H.R. 3762  54                       On the Motion    Rejected
# 00316  H.R. 3762  10                    On the Amendment   Agreed to
# 00317  H.R. 3762  52                       On the Motion    Rejected
# 00318  H.R. 3762  44                       On the Motion    Rejected
# 00319  H.R. 3762  54                       On the Motion    Rejected
# 00320  H.R. 3762  46                       On the Motion    Rejected
# 00321  H.R. 3762  50                       On the Motion    Rejected
# 00322  H.R. 3762  52                       On the Motion    Rejected
# 00323  H.R. 3762  89                    On the Amendment    Rejected
# 00324  H.R. 3762  39                    On the Amendment   Agreed to
# 00325  H.R. 3762  45                    On the Amendment    Rejected
# 00326  H.R. 3762  47                       On the Motion    Rejected
# 00327  H.R. 3762  54                       On the Motion    Rejected
# 00328  H.R. 3762  53                       On the Motion    Rejected
# 00329  H.R. 3762  47               On Passage of the Bill     Passed
# 00330    H.R. 22  22                        On the Motion  Agreed to
# 00331    H.R. 22  16             On the Conference Report  Agreed to
# 00332       PN18   0                    On the Nomination  Confirmed
# 00333    S. 1177  12                On the Cloture Motion  Agreed to
# 00334    S. 1177  12             On the Conference Report  Agreed to
# 00335       PN64  34                    On the Nomination  Confirmed
# 00336  H.R. 2029  26                On the Cloture Motion  Agreed to
# 00337  H.R. 2029  67               On the Motion to Table   Rejected
# 00338  H.R. 2029  25                        On the Motion  Agreed to
# 00339  H.R. 2029  33                        On the Motion  Agreed to
#
#                                                    title vote_date  \
# 00001  Warren Amdt. No. 1; In the nature of a substit...    08-Jan
# 00002  H.R. 26; A bill to extend the termination date...    08-Jan
# 00003  Motion to Invoke Cloture on the Motion to Proc...    12-Jan
# 00004  Motion to Table Markey Amdt. No. 13; To ensure...    20-Jan
# 00005  Motion to Table Franken Amdt. No. 17; To requi...    20-Jan
# 00006  Portman Amdt. No. 3 As Modified; To promote en...    20-Jan
# 00007  Lee Amdt. No. 33; To conform citizen suits und...    21-Jan
# 00008  Durbin Amdt. No. 69; To ensure that the storag...    21-Jan
# 00009  Toomey Amdt. No. 41; To continue cleaning up f...    21-Jan
# 00010  Whitehouse Amdt. No. 29; To express the sense ...    21-Jan
# 00011  Hoeven Amdt. No. 87, As Modified; To express t...    21-Jan
# 00012  Schatz Amdt. No. 58; To express the sense of C...    21-Jan
# 00013  Boxer Amdt. No. 113; To express the sense of C...    22-Jan
# 00014  Fischer Amdt. No. 18, As Modified; To provide ...    22-Jan
# 00015  Motion to Table Manchin Amdt. No. 99; To expre...    22-Jan
# 00016  Motion to Table Sanders Amdt. No. 24; To expre...    22-Jan
# 00017  Lee Amdt. No. 71; To require a procedure for i...    22-Jan
# 00018  Murkowski Amdt. No. 123; To express the sense ...    22-Jan
# 00019  Wyden Amdt. No. 27; To amend the Internal Reve...    22-Jan
# 00020  Blunt Amdt. No. 78 As Modified; To express the...    22-Jan
# 00021  Cornyn Amdt. No. 126 As Modified; To ensure pr...    22-Jan
# 00022  Menendez Amdt. No. 72 As Modified; To ensure p...    22-Jan
# 00023  Motion to Instruct the Sgt. at Arms; A bill to...    22-Jan
# 00024  Motion to Table Markey Amdt. No. 25; To ensure...    22-Jan
# 00025  Motion to Table Carper Amdt. No. 121; To impos...    22-Jan
# 00026  Motion to Table Whitehouse Amdt. No. 28; To re...    22-Jan
# 00027  Motion to Table Leahy Amdt. No. 30; To strike ...    22-Jan
# 00028  Motion to Table Reed Amdt. No. 74; To express ...    22-Jan
# 00029  Motion to Invoke Cloture on the Murkowski Amdt...    26-Jan
# 00030  Motion to Invoke Cloture on S. 1; A bill to ap...    26-Jan
# ...                                                  ...       ...
# 00310  Nomination Gayle Smith, of Ohio, to be Adminis...    30-Nov
# 00311  Motion to Table Murray Amdt. No. 2876; To ensu...    03-Dec
# 00312  Johnson Amdt. No. 2875; To amend the Patient P...    03-Dec
# 00313  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00314       Collins Amdt. No. 2885; To improve the bill.    03-Dec
# 00315  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00316  Heller Amdt. No. 2882; To strike the reinstate...    03-Dec
# 00317  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00318  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00319  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00320  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00321  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00322  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00323  Paul Amdt. No. 2899; To prevent the entry of e...    03-Dec
# 00324  Coats Amdt. No. 2888; To amend the Internal Re...    03-Dec
# 00325  Paul Amdt. No. 2915; To restore Second Amendme...    03-Dec
# 00326  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00327  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00328  Motion to Waive All Applicable Budgetary Disci...    03-Dec
# 00329  H.R. 3762 As Amended; A bill to provide for re...    03-Dec
# 00330  Motion to Waive Rule XXVIII Relative to Sectio...    03-Dec
# 00331  Conference Report to Accompany H.R. 22; An act...    03-Dec
# 00332  Confirmation Travis Randall McDonough, of Tenn...    07-Dec
# 00333  Motion to Invoke Cloture Re: Conference Report...    08-Dec
# 00334  Conference Report to Accompany S.1177; An orig...    09-Dec
# 00335  Confirmation Alissa M. Starzak, of New York, t...    14-Dec
# 00336  Motion to Invoke Cloture on the Motion to Conc...    18-Dec
# 00337  Motion to Table the First House Amendment to t...    18-Dec
# 00338  Motion to Waive All Applicable Budgetary Disci...    18-Dec
# 00339  Motion to Concur in the House Amendments to th...    18-Dec
#
#       vote_number yea
# 00001       00001  31
# 00002       00002  93
# 00003       00003  63
# 00004       00004  57
# 00005       00005  53
# 00006       00006  94
# 00007       00007  54
# 00008       00008  41
# 00009       00009  54
# 00010       00010  98
# 00011       00011  59
# 00012       00012  50
# 00013       00013  55
# 00014       00014  54
# 00015       00015  53
# 00016       00016  56
# 00017       00017  51
# 00018       00018  75
# 00019       00019  50
# 00020       00020  51
# 00021       00021  64
# 00022       00022  43
# 00023       00023  89
# 00024       00024  53
# 00025       00025  57
# 00026       00026  52
# 00027       00027  53
# 00028       00028  49
# 00029       00029  53
# 00030       00030  53
# ...           ...  ..
# 00310       00310  79
# 00311       00311  54
# 00312       00312  56
# 00313       00313  45
# 00314       00314  48
# 00315       00315  46
# 00316       00316  90
# 00317       00317  47
# 00318       00318  55
# 00319       00319  45
# 00320       00320  53
# 00321       00321  48
# 00322       00322  47
# 00323       00323  10
# 00324       00324  60
# 00325       00325  54
# 00326       00326  52
# 00327       00327  45
# 00328       00328  46
# 00329       00329  52
# 00330       00330  77
# 00331       00331  83
# 00332       00332  89
# 00333       00333  84
# 00334       00334  85
# 00335       00335  45
# 00336       00336  72
# 00337       00337  31
# 00338       00338  73
# 00339       00339  65
#
# [339 rows x 8 columns]

# %%
new_index = []
for val in bills_114_2.index.values:
    i = int(val)
    new_num = i+339
    new_index.append(new_num)

# %%
new_index
bills_114_2.index = new_index

# %%
bills_114_2.head()
# Out:
#            issue nay                             question     result  \
# 340         PN11   6                    On the Nomination  Confirmed
# 341      S. 2232  44  On Cloture on the Motion to Proceed   Rejected
# 342        PN367  36                    On the Nomination  Confirmed
# 343    H.R. 4038  43                On the Cloture Motion   Rejected
# 344  S.J.Res. 22  40                On the Cloture Motion   Rejected
#
#                                                  title vote_date vote_number  \
# 340  Nomination Luis Felipe Restrepo, of Pennsylvan...    11-Jan       00001
# 341  Motion to Invoke Cloture on the Motion to Proc...    12-Jan       00002
# 342  Confirmation Wilhelmina Marie Wright, of Minne...    19-Jan       00003
# 343  Motion to Invoke Cloture on the Motion to Proc...    20-Jan       00004
# 344  Motion to Invoke Cloture on the Veto Message t...    21-Jan       00005
#
#     yea
# 340  82
# 341  53
# 342  58
# 343  55
# 344  52

# %%
all_bills = bills_114_1.append(bills_114_2)

# %%
all_bills.sample(10)
# Out:
#              issue nay                             question     result  \
# 00265  H.J.Res. 61  42               On the Cloture Motion    Rejected
# 00308      S. 1177   6                On the Cloture Motion  Agreed to
# 446      H.R. 2578  42               On the Motion to Table  Agreed to
# 00235      S. 1177  64                    On the Amendment    Rejected
# 342          PN367  36                    On the Nomination  Confirmed
# 00162       S. 178   2                    On the Amendment   Agreed to
# 00258      H.R. 22  38                    On the Amendment   Agreed to
# 00176    H.R. 1314  45  On Cloture on the Motion to Proceed   Rejected
# 415      H.R. 2577  28                       On the Motion   Agreed to
# 00185         PN19   0                    On the Nomination  Confirmed
#
#                                                    title vote_date  \
# 00265  Motion to Invoke Cloture on McConnell Amdt. No...    15-Sep
# 00308  Motion to Invoke Cloture on the Motion to Disa...    18-Nov
# 446    Motion to Table the Motion to Commit with Inst...    20-Jun
# 00235  Lee Amdt No. 2162; To amend the Elementary and...    14-Jul
# 342    Confirmation Wilhelmina Marie Wright, of Minne...    19-Jan
# 00162  Kirk Amdt. No. 273 As Modified; To amend title...    22-Apr
# 00258  McConnell Amdt. No. 2266 As Amended; In the na...    29-Jul
# 00176  Motion to Invoke Cloture on the Motion to Proc...    12-May
# 415    Motion to Waive All Applicable Budgetary Disci...    19-May
# 00185  Confirmation Jose Rolando Olvera, Jr., of Texa...    21-May
#
#       vote_number  yea
# 00265       00265   56
# 00308       00308   91
# 446         00107   56
# 00235       00235   32
# 342         00003   58
# 00162       00162   97
# 00258       00258   62
# 00176       00176   52
# 415         00076   70
# 00185       00185  100

# %%
all_bills.to_csv('all_bills.csv')
